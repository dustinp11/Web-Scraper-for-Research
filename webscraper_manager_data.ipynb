# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# %%
url = "https://www.baseball-reference.com/managers/"
response = requests.get(url)

# %%
def get_manager_urls(url) -> dict:
    """Gets the urls of all the managers given the team url."""
    manager_urls = {}
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table_info = soup.find('div', 'table_container').find('table', 'sortable').find_all('tr')
    del table_info[0]
    for row in table_info:
        if 'thead' in row.get('class', []):
            continue
        year_max_td = row.find('td', {'data-stat': 'year_max'})
        year_max = year_max_td.text.strip()
        if int(year_max) >= 2007:
            
            manager_tag = row.find('td', {'data-stat': 'manager'}).find('a')
            manager_url = "https://www.baseball-reference.com" + manager_tag['href']
            manager_urls[manager_tag.text.strip()] = manager_url

    return manager_urls

# %%
managers_url = get_manager_urls(url)
print(len(managers_url))
# Out:
# 122

# %%
team_name_mapping = {
    'Anaheim Angels': 'Los Angeles Angels',
    'Los Angeles Angels of Anaheim': 'Los Angeles Angels',
    'Florida Marlins': 'Miami Marlins',
    'Tampa Bay Devil Rays': 'Tampa Bay Rays',
    'Montreal Expos': 'Washington Nationals',
}

def normalize_team_name(team_name):
    return team_name_mapping.get(team_name, team_name)

# %%
def get_managerial_data(manager_name, manager_url) -> list:
    """Gets the manager's data and their tendencies."""
    data = {'Year': [], "Team": [], "Manager_name": [], "Manager_team_career": [],
           "Manager_MLB_career": [], "steal_2nd": [], "steal_3rd": [],
           "sac_bunts": [], "intentional_walks": [], "Substitutions_PH/G": [],
           "Substitutions_PR/G": [], "Substitutions_P/G": []}
    team_history = {}
    response = requests.get(manager_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    try:
        manager_stats_table = soup.find('div', id='all_manager_stats').find('div', 'table_container').find('tbody').find_all('tr')
        manager_tendencies_table = soup.find('div', id='all_manager_tendencies').find('div', 'table_container').find('tbody').find_all('tr')
    except AttributeError:
        return []
    merged_data = zip(manager_stats_table, manager_tendencies_table)
    for row in merged_data:
        year = row[0].find('td', {'data-stat': 'year_ID'}).text.strip()
        if year and int(year) <= 2023:
            year = int(year)
            age = int(row[0].find('td', {'data-stat': 'age'}).text.strip())
            team = normalize_team_name(row[0].find('td', {'data-stat': 'team_ID'}).text.strip())
            team_history[year] = team
            previous_year = year - 1
            team_career = 1
            while previous_year in team_history:
                if team_history[previous_year] == team:
                    team_career += 1
                    previous_year -= 1
                else:
                    break
            mlb_career = len(data['Year']) + 1 if data['Year'] else 1
            
            second_b_rate = row[1].find('td', {'data-stat': 'steal_2b_rate'}).text.strip()
            third_b_rate = row[1].find('td', {'data-stat': 'steal_3b_rate'}).text.strip()
            sac_rate = row[1].find('td', {'data-stat': 'sac_bunt_rate'}).text.strip()
            intentional_walks = row[1].find('td', {'data-stat': 'ibb_rate'}).text.strip()
            sub_phg = row[1].find('td', {'data-stat': 'pinch_hitters'}).text.strip()
            sub_prg = row[1].find('td', {'data-stat': 'pinch_runners'}).text.strip()
            sub_pg = row[1].find('td', {'data-stat': 'pitchers_used_per_game'}).text.strip()
            data['Year'].append(year)
            data['Team'].append(team)
            data['Manager_name'].append(manager_name)
            data['Manager_team_career'].append(team_career)
            data['Manager_MLB_career'].append(mlb_career)
            data['steal_2nd'].append(second_b_rate)
            data['steal_3rd'].append(third_b_rate)
            data['sac_bunts'].append(sac_rate)
            data['intentional_walks'].append(intentional_walks)
            data['Substitutions_PH/G'].append(sub_phg)
            data['Substitutions_PR/G'].append(sub_prg)
            data['Substitutions_P/G'].append(sub_pg)
    return [list(x) for x in zip(*data.values())]

# %%
def write_to_csv(data: []):
    """Writes the data into a csv."""
    with open("L:/RA_work/JAY/datasets/final/manager_data.csv", mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerows([["Year", "Team", "Manager_name", "Manager_team_career", "Manager_MLB_career", 
                           "steal_2nd", "steal_3rd", "sac_bunts", "intentional_walks", "Substitutions_PH/G", 
                           "Substitutions_PR/G", "Substitutions_P/G"]])
        writer.writerows(data)

# %%
total_data = []
for name, url in managers_url.items():
    print(f"Fetching {name}'s data from: {url}")
    manager_data = get_managerial_data(name, url)
    total_data.extend(manager_data)
    
    time.sleep(4)
# Out:
# Fetching Manny Acta's data from: https://www.baseball-reference.com/managers/actama99.shtml
# Fetching Sandy Alomar's data from: https://www.baseball-reference.com/managers/alomasa02.shtml
# Fetching Brad Ausmus's data from: https://www.baseball-reference.com/managers/ausmubr01.shtml
# Fetching Dusty Baker's data from: https://www.baseball-reference.com/managers/bakerdu01.shtml
# Fetching Rocco Baldelli's data from: https://www.baseball-reference.com/managers/baldero01.shtml
# Fetching Jeff Banister's data from: https://www.baseball-reference.com/managers/banisje01.shtml
# Fetching Rod Barajas's data from: https://www.baseball-reference.com/managers/barajro01.shtml
# Fetching Tony Beasley's data from: https://www.baseball-reference.com/managers/beaslto99.shtml
# Fetching Buddy Bell's data from: https://www.baseball-reference.com/managers/bellbu01.shtml
# Fetching David Bell's data from: https://www.baseball-reference.com/managers/bellda01.shtml
# Fetching Bud Black's data from: https://www.baseball-reference.com/managers/blackbu02.shtml
# Fetching Bruce Bochy's data from: https://www.baseball-reference.com/managers/bochybr01.shtml
# Fetching Tim Bogar's data from: https://www.baseball-reference.com/managers/bogarti01.shtml
# Fetching Aaron Boone's data from: https://www.baseball-reference.com/managers/booneaa01.shtml
# Fetching Daren Brown's data from: https://www.baseball-reference.com/managers/brownda99.shtml
# Fetching Miguel Cairo's data from: https://www.baseball-reference.com/managers/cairomi01.shtml
# Fetching Mickey Callaway's data from: https://www.baseball-reference.com/managers/callami01.shtml
# Fetching Kevin Cash's data from: https://www.baseball-reference.com/managers/cashke01.shtml
# Fetching Dave Clark's data from: https://www.baseball-reference.com/managers/clarkda05.shtml
# Fetching Terry Collins's data from: https://www.baseball-reference.com/managers/collite99.shtml
# Fetching Cecil Cooper's data from: https://www.baseball-reference.com/managers/coopece01.shtml
# Fetching Ron Roenicke's data from: https://www.baseball-reference.com/managers/roeniro01.shtml
# Fetching Luis Rojas's data from: https://www.baseball-reference.com/managers/rojaslu99.shtml
# Fetching David Ross's data from: https://www.baseball-reference.com/managers/rossda01.shtml
# Fetching John Russell's data from: https://www.baseball-reference.com/managers/russejo02.shtml
# Fetching Juan Samuel's data from: https://www.baseball-reference.com/managers/samueju01.shtml
# Fetching Ryne Sandberg's data from: https://www.baseball-reference.com/managers/sandbry01.shtml
# Fetching John Schneider's data from: https://www.baseball-reference.com/managers/schnejo99.shtml
# Fetching Skip Schumaker's data from: https://www.baseball-reference.com/managers/schumsk01.shtml
# Fetching Mike Scioscia's data from: https://www.baseball-reference.com/managers/sciosmi01.shtml
# Fetching Scott Servais's data from: https://www.baseball-reference.com/managers/servasc01.shtml
# Fetching Derek Shelton's data from: https://www.baseball-reference.com/managers/sheltde99.shtml
# Fetching Mike Shildt's data from: https://www.baseball-reference.com/managers/shildmi99.shtml
# Fetching Buck Showalter's data from: https://www.baseball-reference.com/managers/showabu99.shtml
# Fetching Grady Sizemore's data from: https://www.baseball-reference.com/managers/sizemgr01.shtml
# Fetching Brian Snitker's data from: https://www.baseball-reference.com/managers/snitkbr99.shtml
# Fetching Dale Sveum's data from: https://www.baseball-reference.com/managers/sveumda01.shtml
# Fetching Rob Thomson's data from: https://www.baseball-reference.com/managers/thomsro99.shtml
# Fetching Jayce Tingler's data from: https://www.baseball-reference.com/managers/tinglja99.shtml
# Fetching Joe Torre's data from: https://www.baseball-reference.com/managers/torrejo01.shtml
# Fetching Jim Tracy's data from: https://www.baseball-reference.com/managers/tracyji01.shtml
# Fetching Alan Trammell's data from: https://www.baseball-reference.com/managers/trammal01.shtml
# Fetching Dave Trembley's data from: https://www.baseball-reference.com/managers/trembda99.shtml
# Fetching Bobby Valentine's data from: https://www.baseball-reference.com/managers/valenbo02.shtml
# Fetching Robin Ventura's data from: https://www.baseball-reference.com/managers/venturo01.shtml
# Fetching Stephen Vogt's data from: https://www.baseball-reference.com/managers/vogtst01.shtml
# Fetching Don Wakamatsu's data from: https://www.baseball-reference.com/managers/wakamdo01.shtml
# Fetching Ron Washington's data from: https://www.baseball-reference.com/managers/washiro01.shtml
# Fetching Eric Wedge's data from: https://www.baseball-reference.com/managers/wedgeer01.shtml
# Fetching Walt Weiss's data from: https://www.baseball-reference.com/managers/weisswa01.shtml
# Fetching Matt Williams's data from: https://www.baseball-reference.com/managers/willima04.shtml
# Fetching Dan Wilson's data from: https://www.baseball-reference.com/managers/wilsoda01.shtml
# Fetching Chris Woodward's data from: https://www.baseball-reference.com/managers/woodwch01.shtml
# Fetching Ned Yost's data from: https://www.baseball-reference.com/managers/yostne01.shtml

# %%
sorted_data = sorted(total_data, key=lambda x: x[0])
data = [x for x in sorted_data if x[0] >= 2007]
write_to_csv(data)
